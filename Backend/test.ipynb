# %%
from dotenv import load_dotenv
import os

from langchain_openai import ChatOpenAI
from langchain_nvidia_ai_endpoints import ChatNVIDIA

load_dotenv()

def test_model(name, client):
    print(f"\nTesting: {name}")

    try:
        response = client.invoke("Reply with WORKING")

        print("SUCCESS")
        print(response.content)

    except Exception as e:
        print("FAILED")
        print(type(e).__name__)
        print(e)

# %%
openrouter = ChatOpenAI(
    model="deepseek/deepseek-chat-v3-0324",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url="https://openrouter.ai/api/v1",
)

test_model("OpenRouter", openrouter)
# Out:
# Testing: OpenRouter
# SUCCESS
# Here’s your reply:
#
# **"WORKING"**
#
# Let me know if you'd like anything else! 😊

# %%
deepseek = ChatOpenAI(
    model="deepseek-chat",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com/v1",
)

test_model("DeepSeek", deepseek)
# Out:
# Testing: DeepSeek
# FAILED
# APIStatusError
# Error code: 402 - {'error': {'message': 'Insufficient Balance', 'type': 'unknown_error', 'param': None, 'code': 'invalid_request_error'}}

# %%
moonshot = ChatOpenAI(
    api_key=os.getenv("MOONSHOT_API_KEY"),
    base_url="https://api.moonshot.ai/v1",
)

test_model("Moonshot", moonshot)
# Out:
# Testing: Moonshot
# FAILED
# RateLimitError
# Error code: 429 - {'error': {'message': 'Your account org-850bc86eac1242f0b66f00e65ad8754d <ak-fajdn5b3xufi11cfxra1> is suspended due to insufficient balance, please recharge your account or check your plan and billing details', 'type': 'exceeded_current_quota_error'}}

# %%
nvidia = ChatNVIDIA(
    model="meta/llama-3.3-70b-instruct",
    api_key=os.getenv("NVIDIA_API_KEY"),
)

test_model("Nvidia", nvidia)
# Out:
# Testing: Nvidia
# SUCCESS
# WORKING
